# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(1,21)
y = np.random.randint(1,100,20)

# %%
plt.scatter(x,y,marker='o',c='r',s=88,ec ='k',lw = 2)

# %%
x = ['Mon','Tue','Wed','Thu','Fri']
y =[50,70,35,90,40]
plt.figure (figsize =  [4,2])
plt.bar(x, y,color='b',alpha=0.5,hatch = '\//-|')
plt.title('Week')
# Out:
# Text(0.5, 1.0, 'Week')

# %%
plt.figure (figsize =  [4,2])
plt.barh(x, y,color='b',alpha=0.5,hatch = '\//-|')
# Out:
# <BarContainer object of 5 artists>

# %%
x = np.arange(1,6)
y1 = np.random.randint(1,50,5)
y2 = np.random.randint(1,50,5)
y3 = np.random.randint(1,50,5)

# %%
plt.figure(figsize=[4,2])
plt.bar(x,y1)
plt.bar(x,y2,alpha=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=[4,2])
bw = 0.2
plt.bar(x,y1,width=bw)
plt.bar(x+bw,y2,width=bw)
plt.bar(x+bw*2,y3,width=bw)
plt.xticks(x+bw,['A','B','2002','2003','2004'])
plt.legend(loc = 'best')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data = np.random.randint(1,100,200)
plt.hist(data,bins=20,ec='k')
# Out:
# (array([12.,  6., 11., 13.,  9., 11.,  9.,  8., 16.,  6.,  8.,  8.,  5.,
#         10., 13., 11.,  7., 12.,  7., 18.]),
#  array([ 1. ,  5.9, 10.8, 15.7, 20.6, 25.5, 30.4, 35.3, 40.2, 45.1, 50. ,
#         54.9, 59.8, 64.7, 69.6, 74.5, 79.4, 84.3, 89.2, 94.1, 99. ]),
#  <BarContainer object of 20 artists>)

# %%
data = [45,20,25,5,10]
lb = ['Chorme','Edge','Firefox','Opera','Safari']
plt.pie(data,labels=lb,explode=[0,0,0.2,0,0.1],shadow = True,autopct="%.1f%%")
plt.title("Browser Market Share")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dic = {"Math":[10,40,78,55,60],
       "Eng":[99,23,56,87,65],
       "Thai":[78,50,60,34,25]
       }
df = pd.DataFrame(dic)
data = [df['Math'],df['Eng'],df['Thai']]
plt.boxplot(data,vert=True,widths=0.3,labels = ["Math","Eng","Thai"],patch_artist=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a figure and an axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Generate some data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Plot the data
ax.plot_surface(x, y, z, cmap='viridis')

# Add labels and a title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot')

# Show the plot
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x= np.random.randint(1,100,5)
y= np.random.randint(1,100,5) 
z= np.random.randint(1,100,5)
ax.plot3D(x,y,z,'o-.r')
